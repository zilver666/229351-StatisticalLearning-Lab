# %% [markdown]
# <a href="https://colab.research.google.com/github/zilver666/229352-StatisticalLearning-Lab/blob/main/229351_LAB07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ปฏิบัติการครั้งที่ 7 กระบวนวิชา 229351 Statistical Learning for Data Science
#
# คำชี้แจง
#
# ให้เริ่มทำปฏิบัติการจาก colab notebook หรือไฟล์ *.ipynb ที่กำหนดให้ จากนั้นบันทึกไว้เป็นไฟล์ *.pdf แล้วส่งใน Assignments

# %% [markdown]
# ดาวน์โหลดข้อมูลรถยนต์ชนิดต่างใน link ข้างล่างนี้
# https://donlapark.pages.dev/229351/data/elecequip.csv

# %%
# uploading the csv file to colab

# !wget -O elecequip.csv https://donlapark.pages.dev/229351/data/elecequip.csv
# Out:
# --2025-09-10 12:58:35--  https://donlapark.pages.dev/229351/data/elecequip.csv
# Resolving donlapark.pages.dev (donlapark.pages.dev)... 172.66.47.56, 172.66.44.200, 2606:4700:310c::ac42:2f38, ...
# Connecting to donlapark.pages.dev (donlapark.pages.dev)|172.66.47.56|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3844 (3.8K) [text/csv]
# Saving to: ‘elecequip.csv’
#
# elecequip.csv       100%[===================>]   3.75K  --.-KB/s    in 0s
#
# 2025-09-10 12:58:35 (48.1 MB/s) - ‘elecequip.csv’ saved [3844/3844]

# %%
# import module ที่ต้องใช้
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
data = pd.read_csv('elecequip.csv', parse_dates=['time'], index_col='time')
data
# Out:
#             Unnamed: 0  value
# time
# 1996-01-01           1  79.35
# 1996-02-01           2  75.78
# 1996-03-01           3  86.32
# 1996-04-01           4  72.60
# 1996-05-01           5  74.86
# ...                ...    ...
# 2011-11-01         191  93.37
# 2011-12-01         192  98.34
# 2012-01-01         193  86.44
# 2012-02-01         194  85.04
# 2012-03-01         195  97.80
#
# [195 rows x 2 columns]

# %%
plt.figure(figsize=(12,6))
plt.plot(data["value"]);

# %%
train = data.loc['1996-01-01':'2009-12-01'].copy()
test = data.loc['2010-01-01':'2012-03-01'].copy()
train, test
# Out:
# (            Unnamed: 0   value
#  time
#  1996-01-01           1   79.35
#  1996-02-01           2   75.78
#  1996-03-01           3   86.32
#  1996-04-01           4   72.60
#  1996-05-01           5   74.86
#  ...                ...     ...
#  2009-08-01         164   65.36
#  2009-09-01         165   88.09
#  2009-10-01         166   84.60
#  2009-11-01         167   88.09
#  2009-12-01         168  102.52
#
#  [168 rows x 2 columns],
#              Unnamed: 0   value
#  time
#  2010-01-01         169   79.28
#  2010-02-01         170   78.74
#  2010-03-01         171   94.62
#  2010-04-01         172   84.66
#  2010-05-01         173   85.20
#  2010-06-01         174  103.94
#  2010-07-01         175   89.87
#  2010-08-01         176   78.14
#  2010-09-01         177   96.50
#  2010-10-01         178   94.68
#  2010-11-01         179  101.77
#  2010-12-01         180  103.48
#  2011-01-01         181   92.57
#  2011-02-01         182   89.16
#  2011-03-01         183  104.48
#  2011-04-01         184   89.45
#  2011-05-01         185   93.40
#  2011-06-01         186  102.90
#  2011-07-01         187   93.77
#  2011-08-01         188   77.58
#  2011-09-01         189   95.04
#  2011-10-01         190   91.77
#  2011-11-01         191   93.37
#  2011-12-01         192   98.34
#  2012-01-01         193   86.44
#  2012-02-01         194   85.04
#  2012-03-01         195   97.80)

# %%
# Add or change values

data.loc['2012-03-02','value'] = 86

data
# Out:
#             Unnamed: 0  value
# time
# 1996-01-01         1.0  79.35
# 1996-02-01         2.0  75.78
# 1996-03-01         3.0  86.32
# 1996-04-01         4.0  72.60
# 1996-05-01         5.0  74.86
# ...                ...    ...
# 2011-12-01       192.0  98.34
# 2012-01-01       193.0  86.44
# 2012-02-01       194.0  85.04
# 2012-03-01       195.0  97.80
# 2012-03-02         NaN  86.00
#
# [196 rows x 2 columns]

# %% [markdown]
# # Moving average

# %%
data['MA'] = data['value'].rolling(window=5,center=True).mean()
#data['MA'] = data['value'].rolling(window=12,center=True).mean().rolling(window=2).mean().shift(-1)

data.head(12)
# Out:
#             Unnamed: 0  value      MA
# time
# 1996-01-01         1.0  79.35     NaN
# 1996-02-01         2.0  75.78     NaN
# 1996-03-01         3.0  86.32  77.782
# 1996-04-01         4.0  72.60  78.674
# 1996-05-01         5.0  74.86  79.478
# 1996-06-01         6.0  83.81  74.696
# 1996-07-01         7.0  79.80  77.258
# 1996-08-01         8.0  62.41  78.908
# 1996-09-01         9.0  85.41  78.988
# 1996-10-01        10.0  83.11  80.968
# 1996-11-01        11.0  84.21  84.214
# 1996-12-01        12.0  89.70  82.616

# %%
plt.figure(figsize=(12,6))
plt.plot(data['value'])
plt.plot(data['MA']);

# %% [markdown]
# # Classical decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib as mpl

mpl.rc("figure", figsize=(12,6))
result_add = seasonal_decompose(train['value'], model='additive', period=12)

result_add.plot();

# %%
result_mul = seasonal_decompose(train['value'], model='multiplicative', period=12)

result_mul.plot();

# %% [markdown]
# ### เรียกดูแต่ละส่วน

# %%
print(result_add.trend)
print(result_add.seasonal)
print(result_add.resid)
print(result_add.observed)
# Out:
# time
# 1996-01-01   NaN
# 1996-02-01   NaN
# 1996-03-01   NaN
# 1996-04-01   NaN
# 1996-05-01   NaN
#               ..
# 2009-08-01   NaN
# 2009-09-01   NaN
# 2009-10-01   NaN
# 2009-11-01   NaN
# 2009-12-01   NaN
# Name: trend, Length: 168, dtype: float64
# time
# 1996-01-01    -5.985857
# 1996-02-01    -5.957941
# 1996-03-01     8.183245
# 1996-04-01    -6.462428
# 1996-05-01    -5.041178
#                 ...
# 2009-08-01   -17.138902
# 2009-09-01     8.178886
# 2009-10-01     3.378341
# 2009-11-01     3.644335
# 2009-12-01    11.289463
# Name: seasonal, Length: 168, dtype: float64
# time
# 1996-01-01   NaN
# 1996-02-01   NaN
# 1996-03-01   NaN
# 1996-04-01   NaN
# 1996-05-01   NaN
#               ..
# 2009-08-01   NaN
# 2009-09-01   NaN
# 2009-10-01   NaN
# 2009-11-01   NaN
# 2009-12-01   NaN
# Name: resid, Length: 168, dtype: float64
# time
# 1996-01-01     79.35
# 1996-02-01     75.78
# 1996-03-01     86.32
# 1996-04-01     72.60
# 1996-05-01     74.86
#                ...
# 2009-08-01     65.36
# 2009-09-01     88.09
# 2009-10-01     84.60
# 2009-11-01     88.09
# 2009-12-01    102.52
# Name: value, Length: 168, dtype: float64

# %% [markdown]
# ### ปฏิบัติการครั้งที่ 7
# 1. สร้างโมเดลเพื่อการทำนายดังนี้
# 1.1 แบ่งข้อมูลออกเป็น 2 ส่วน
#    - training set: วันที่ 1996-01-01 ถึง 2009-12-01
#    - test set: วันที่ 2010-01-01 ถึง 2012-03-01
# 1.2 แยกส่วนประกอบ $y_t=S_t+T_t+R_t$ บน training set
# 1.3 สร้าง time series ชุดใหม่ที่แสดงถึงทำนายค่าบน test set โดยนำค่า $T_t+R_t$ ของวันล่าสุดใน training set ที่มีค่า $T_t$ มาบวกกับแต่ละค่าใน $S_t$ จากวันที่ วันที่ 2010-01-01 ถึง 2012-03-01
# 3. คำนวณ RMSE โดยใช้ฟังก์ชัน `rmse` ข้างล่าง
# 4. แสดงแผนภาพข้อมูล elecequip และค่าทำนายที่ได้

# %%
def rmse(y_true,y_pred):
  # Inputs
  # y_true: actual value, y_pred: predicted values
  # Output: RMSE between y_true and y_pred
  return np.sqrt(np.mean(np.square(y_true-y_pred)))

# %%
S_month = result_add.seasonal.groupby(result_add.seasonal.index.month).mean()
A_last = (result_add.trend + result_add.resid).dropna().iloc[-1]
yhat = A_last + np.array([S_month[m] for m in test.index.month])
ts_new = pd.Series(yhat, index=test.index, name='pred')
print(f"{rmse(test['value'].to_numpy(), ts_new.to_numpy()):.6f}")
# Out:
# 14.589767

# %%
ax = data['value'].plot(figsize=(20,8))
ts_new.plot(ax=ax, marker='o')
# Out:
# <Axes: xlabel='time'>
